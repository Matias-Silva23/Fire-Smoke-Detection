# %%
# !pip install roboflow ultralytics -q

from ultralytics import YOLO

import shutil
shutil.copy(
    "/kaggle/input/models/matiassilvapalomo/v2/other/default/1/best.pt",
    "/kaggle/working/best.pt"
)

model= YOLO("/kaggle/working/best.pt")

model.export(
    format="torchscript",
    optimize= True,
    nms= False
)
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 113 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# PyTorch: starting from '/kaggle/working/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (83.6 MB)
#
# TorchScript: starting export with torch 2.10.0+cpu...
# TorchScript: optimizing for mobile...
# TorchScript: export success ✅ 13.0s, saved as '/kaggle/working/best.torchscript' (166.5 MB)
#
# Export complete (17.8s)
# Results saved to /kaggle/working/best.torchscript
# Predict:         yolo predict task=detect model=/kaggle/working/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=/kaggle/working/best.torchscript imgsz=640 data=/kaggle/working/Fire-Smoke-Detection-Yolov11-1/data.yaml
# ...

# %%
import torch

model = torch.jit.load("/kaggle/working/best.torchscript")
model.eval()

x = torch.randn(1,3,640,640)

with torch.no_grad():
    y = model(x)

print(type(y))
print(y.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([1, 6, 8400])
